# %%
# USER OPTIONS
# define tokenizer name - should be one among the keys in the cell below
tokenizer_name = 'ChordSymbolTokenizer' # or any other name from the keys in tokenizers dictionary
# tokenizer_name = 'RootTypeTokenizer'
# tokenizer_name = 'PitchClassTokenizer'
# tokenizer_name = 'RootPCTokenizer'
csvs_folder = 'results/tokenized_old/bart_0.8/'

# %%
from data_utils import MergedMelHarmDataset, PureGenCollator
import os
import numpy as np
from harmony_tokenizers_m21 import ChordSymbolTokenizer, RootTypeTokenizer, \
    PitchClassTokenizer, RootPCTokenizer, GCTRootPCTokenizer, \
    GCTSymbolTokenizer, GCTRootTypeTokenizer, MelodyPitchTokenizer, \
    MergedMelHarmTokenizer
import pandas as pd

# %%
tokenizers = {
    'ChordSymbolTokenizer': ChordSymbolTokenizer,
    'RootTypeTokenizer': RootTypeTokenizer,
    'PitchClassTokenizer': PitchClassTokenizer,
    'RootPCTokenizer': RootPCTokenizer,
    'GCTRootPCTokenizer': GCTRootPCTokenizer,
    'GCTSymbolTokenizer': GCTSymbolTokenizer,
    'GCTRootTypeTokenizer': GCTRootTypeTokenizer
}

# %%
melody_tokenizer = MelodyPitchTokenizer.from_pretrained('saved_tokenizers/MelodyPitchTokenizer')
harmony_tokenizer = tokenizers[tokenizer_name].from_pretrained('saved_tokenizers/' + tokenizer_name)

tokenizer = MergedMelHarmTokenizer(melody_tokenizer, harmony_tokenizer)

# %%
c = pd.read_csv( csvs_folder + tokenizer_name + '.csv' )

# %%
x = c['melody'].iloc[2].split() + c['generated'].iloc[2].split()
# x = c['melody'].iloc[1].split() + c['generated'].iloc[1].split()
# x = c['melody'].iloc[2].split() + c['real'].iloc[2].split()
print(x)
# Out:
# ['<s>', '<bar>', 'ts_4x4', 'position_0x00', '<rest>', 'position_1x50', 'P:74', 'position_2x00', 'P:67', 'position_3x00', 'P:69', '<bar>', 'position_0x00', 'P:71', 'position_1x50', 'P:74', 'position_2x00', 'P:71', 'position_3x00', 'P:69', '<bar>', 'position_0x00', 'P:67', 'position_0x75', 'P:67', 'position_1x50', 'P:69', 'position_2x00', 'P:71', 'position_3x00', 'P:72', '<bar>', 'position_0x00', 'P:74', 'position_0x75', 'P:74', 'position_1x00', 'P:74', 'position_1x50', 'P:74', 'position_2x00', 'P:76', 'position_3x00', 'P:74', '<bar>', 'position_0x00', 'P:72', 'position_1x50', 'P:76', 'position_2x00', 'P:69', 'position_3x00', 'P:71', '<bar>', 'position_0x00', 'P:72', 'position_1x50', 'P:76', 'position_2x00', 'P:72', 'position_3x00', 'P:71', '<bar>', 'position_0x00', 'P:69', 'position_1x50', 'P:71', 'position_2x00', 'P:72', 'position_3x00', 'P:74', '<bar>', 'position_0x00', 'P:76', 'position_0x50', 'P:76', 'position_0x75', 'P:76', 'position_1x25', 'P:76', 'position_1x50', 'P:76', 'position_2x00', 'P:78', 'position_3x00', 'P:76', '<bar>', 'position_0x00', 'P:74', 'position_1x50', 'P:86', 'position_2x00', 'P:91', 'position_3x00', 'P:93', '<h>', '<bar>', '<bar>', 'position_0x00', 'G:maj', 'position_0x75', 'G:maj', 'position_1x50', 'G:maj', 'position_2x00', 'G:maj', 'position_3x00', 'E:min7', '<bar>', 'position_0x00', 'E:min7', 'position_0x75', 'E:min7', 'position_1x50', 'E:min7', 'position_2x00', 'E:min7', 'position_3x00', 'E:min7', '<bar>', 'position_0x00', 'E:min7', 'position_0x75', 'E:min7', 'position_1x50', 'E:min7', 'position_2x00', 'E:min7', 'position_3x00', 'E:min7', '<bar>', 'position_0x00', 'E:min7', 'position_0x75', 'E:min7', 'position_1x50', 'E:min7', 'position_2x00', 'E:min7', 'position_3x00', 'E:min7', '<bar>', 'position_0x00', 'C:maj', 'position_0x75', 'C:maj', 'position_1x50', 'C:maj', 'position_2x00', 'C:maj', 'position_3x00', 'E:min7', '<bar>', 'position_0x00', 'E:min7', 'position_0x75', 'E:min7', 'position_1x50', 'E:min7', 'position_3x00', 'E:min7', '<bar>', 'position_0x00', 'A:min', '<bar>', 'position_0x00', 'A:min', 'position_0x75', 'A:min', 'position_1x50', 'A:min7', 'position_2x00', 'A:min', 'position_3x00', 'A:min', '</s>']

# %%
tokenizer.decode(x, output_format='file', output_path='score.mxl')
tokenizer.decode(x, output_format='text')
# tokenizer.decode(x, output_format='file', output_path='test.midi')
# Out:
# Saved as score.mxl
# {0.0} <music21.stream.Part 0x1ffada78950>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.note.Rest dotted-quarter>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note G>
#         {3.0} <music21.note.Note A>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.note.Note B>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note B>
#         {3.0} <music21.note.Note A>
#     {8.0} <music21.stream.Measure 3 offset=8.0>
#         {0.0} <music21.note.Note G>
#         {0.75} <music21.note.Note G>
#         {1.5} <music21.note.Note A>
#         {2.0} <music21.note.Note B>
#         {3.0} <music21.note.Note C>
#     {12.0} <music21.stream.Measure 4 offset=12.0>
#         {0.0} <music21.note.Note D>
#         {0.75} <music21.note.Note D>
#         {1.0} <music21.note.Note D>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note E>
#         {3.0} <music21.note.Note D>
#     {16.0} <music21.stream.Measure 5 offset=16.0>
#         {0.0} <music21.note.Note C>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note A>
#         {3.0} <music21.note.Note B>
#     {20.0} <music21.stream.Measure 6 offset=20.0>
#         {0.0} <music21.note.Note C>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#     {24.0} <music21.stream.Measure 7 offset=24.0>
#         {0.0} <music21.note.Note A>
#         {1.5} <music21.note.Note B>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note D>
#     {28.0} <music21.stream.Measure 8 offset=28.0>
#         {0.0} <music21.note.Note E>
#         {0.5} <music21.note.Note E>
#         {0.75} <music21.note.Note E>
#         {1.25} <music21.note.Note E>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note F#>
#         {3.0} <music21.note.Note E>
#     {32.0} <music21.stream.Measure 9 offset=32.0>
#         {0.0} <music21.note.Note D>
#         {1.5} <music21.note.Note D>
#         {2.0} <music21.note.Note G>
#         {3.0} <music21.note.Note A>
# {0.0} <music21.stream.Part 0x1ffadcdc590>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.chord.Chord G3 B3 D4>
#         {0.75} <music21.chord.Chord G3 B3 D4>
#         {1.5} <music21.chord.Chord G3 B3 D4>
#         {2.0} <music21.chord.Chord G3 B3 D4>
#         {3.0} <music21.chord.Chord E3 G3 B3 D4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord E3 G3 B3 D4>
#         {0.75} <music21.chord.Chord E3 G3 B3 D4>
#         {1.5} <music21.chord.Chord E3 G3 B3 D4>
#         {2.0} <music21.chord.Chord E3 G3 B3 D4>
#         {3.0} <music21.chord.Chord E3 G3 B3 D4>
#     {8.0} <music21.stream.Measure 4 offset=8.0>
#         {0.0} <music21.chord.Chord E3 G3 B3 D4>
#         {0.75} <music21.chord.Chord E3 G3 B3 D4>
#         {1.5} <music21.chord.Chord E3 G3 B3 D4>
#         {2.0} <music21.chord.Chord E3 G3 B3 D4>
#         {3.0} <music21.chord.Chord E3 G3 B3 D4>
#     {12.0} <music21.stream.Measure 5 offset=12.0>
#         {0.0} <music21.chord.Chord E3 G3 B3 D4>
#         {0.75} <music21.chord.Chord E3 G3 B3 D4>
#         {1.5} <music21.chord.Chord E3 G3 B3 D4>
#         {2.0} <music21.chord.Chord E3 G3 B3 D4>
#         {3.0} <music21.chord.Chord E3 G3 B3 D4>
#     {16.0} <music21.stream.Measure 6 offset=16.0>
#         {0.0} <music21.chord.Chord C3 E3 G3>
#         {0.75} <music21.chord.Chord C3 E3 G3>
#         {1.5} <music21.chord.Chord C3 E3 G3>
#         {2.0} <music21.chord.Chord C3 E3 G3>
#         {3.0} <music21.chord.Chord E3 G3 B3 D4>
#     {20.0} <music21.stream.Measure 7 offset=20.0>
#         {0.0} <music21.chord.Chord E3 G3 B3 D4>
#         {0.75} <music21.chord.Chord E3 G3 B3 D4>
#         {1.5} <music21.chord.Chord E3 G3 B3 D4>
#         {3.0} <music21.chord.Chord E3 G3 B3 D4>
#     {24.0} <music21.stream.Measure 8 offset=24.0>
#         {0.0} <music21.chord.Chord A3 C4 E4>
#     {28.0} <music21.stream.Measure 9 offset=28.0>
#         {0.0} <music21.chord.Chord A3 C4 E4>
#         {0.75} <music21.chord.Chord A3 C4 E4>
#         {1.5} <music21.chord.Chord A3 C4 E4 G4>
#         {2.0} <music21.chord.Chord A3 C4 E4>
#         {3.0} <music21.chord.Chord A3 C4 E4>
